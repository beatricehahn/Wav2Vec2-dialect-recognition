# %% [markdown]
# <a href="https://colab.research.google.com/github/concretelinguist/Wav2Vec2-dialect-recognition/blob/main/487final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Beatrice Hahn**
#
# **LING487 Final Project:**  Comparing Army Brat dialect (DR8) consonants and vowels to New England (DR1), and Southern (DR5) dialects using Wav2Vec2 pretrained model running TIMIT database.
# * particularly interested in "Dawn vs. Don" differences and r's/ l's

# %%
#using driv as director
from google.colab import drive
# allows Collab to access my drive
drive.mount('/content/drive')
# set current directory to the folder with TIMIT files
# %cd /content/drive/MyDrive/LangFolder/
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/LangFolder

# %%
 # !pip install transformers==4.3.2
# Out:
# ...
#      |████████████████████████████████| 1.8 MB 4.9 MB/s
# ...
#      |████████████████████████████████| 895 kB 56.5 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 40.9 MB/s
# ...

# %%
#import libraries

import numpy as np
import matplotlib.pyplot as plt
from transformers import Wav2Vec2Tokenizer, Wav2Vec2ForCTC
import tensorflow.keras.layers as layers
import tensorflow.keras.models as models
from tensorflow.keras import Sequential
import torch
import librosa as lb
import tensorflow as tf

#load model and tokenizer
tokenizer = Wav2Vec2Tokenizer.from_pretrained("facebook/wav2vec2-base-960h")
model = Wav2Vec2ForCTC.from_pretrained("facebook/wav2vec2-base-960h")
# Out:
# Downloading:   0%|          | 0.00/291 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/163 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/85.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.60k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/378M [00:00<?, ?B/s]

# %%
import numpy as np, IPython.display as ipd
import wave, struct

#import in WAV files. 
#use wave.open() for this 
neweng_sample = wave.open('/content/drive/MyDrive/LangFolder/DR1/FAKS0/SI1573.WAV','r')
southern_sample = wave.open('/content/drive/MyDrive/LangFolder/DR5/FGMB0/SI1775.WAV', 'r')
armybrat_sample = wave.open('/content/drive/MyDrive/LangFolder/DR8/MJTC0/SI2090.WAV', 'r')

#all audio has a sampling rate of 16khz. 
#how many seconds of audio can be found by nframes/16khz
print('neweng_sample params =',neweng_sample.getparams()) #nframes=52122. 
length_neweng_sample = 52122/16000
print('length of neweng_sample =',length_neweng_sample) #3.257625 seconds
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-14-e357810d1192> in <module>()
#       4 #import in WAV files.
#       5 #use wave.open() for this
# ----> 6 neweng_sample = wave.open('/content/drive/MyDrive/LangFolder/DR1/FAKS0/SI1573.WAV','r')
#       7 southern_sample = wave.open('/content/drive/MyDrive/LangFolder/DR5/FGMB0/SI1775.WAV', 'r')
#       8 armybrat_sample = wave.open('/content/drive/MyDrive/LangFolder/DR8/MJTC0/SI2090.WAV', 'r')
#
# /usr/lib/python3.7/wave.py in open(f, mode)
#     508             mode = 'rb'
#     509     if mode in ('r', 'rb'):
# --> 510         return Wave_read(f)
#     511     elif mode in ('w', 'wb'):
#     512         return Wave_write(f)
#
# /usr/lib/python3.7/wave.py in __init__(self, f)
#     162         # else, assume it is an open file object already
#     163         try:
# --> 164             self.initfp(f)
# ...

# %%
#load any audio file of your choice

# sample of the new england dialect
speech, rate = lb.load("/content/drive/MyDrive/LangFolder/DR1/FAKS0/SI1573.WAV",sr=16000)
input_values = tokenizer(speech, return_tensors = 'pt').input_values
#Store logits (non-normalized predictions)
logits = model(input_values).logits
#Store predicted id's
predicted_ids = torch.argmax(logits, dim =-1)
#decode the audio to generate text
transcriptions = tokenizer.decode(predicted_ids[0])
print("Sample DR1 sentence: " )
print(transcriptions)

#load any audio file of your choice
speech, rate = lb.load("/content/drive/MyDrive/LangFolder/DR5/FGMB0/SI1775.WAV",sr=16000)
input_values = tokenizer(speech, return_tensors = 'pt').input_values
#Store logits (non-normalized predictions)
logits = model(input_values).logits
#Store predicted id's
predicted_ids = torch.argmax(logits, dim =-1)
#decode the audio to generate text
transcriptions = tokenizer.decode(predicted_ids[0])
print("Sample DR5 sentence: " )
print(transcriptions)

#load any audio file of your choice
speech, rate = lb.load("/content/drive/MyDrive/LangFolder/DR8/MJTC0/SI2090.WAV",sr=16000)
input_values = tokenizer(speech, return_tensors = 'pt').input_values
#Store logits (non-normalized predictions)
logits = model(input_values).logits
#Store predicted id's
predicted_ids = torch.argmax(logits, dim =-1)
#decode the audio to generate text
transcriptions = tokenizer.decode(predicted_ids[0])
print("Sample DR8 sentence: " )
print(transcriptions)
# Out:
# Sample DR1 sentence:
# HIS CAPTAIN WAS THIN AND HAGGARD AND HIS BEAUTIFUL BOOTS WERE WORN AND SHABBY
# Sample DR5 sentence:
# THE BLUE RUG WAS SUSPICIOUSLY BRIGHT AND NEW
# Sample DR8 sentence:
# HE SWUNG IN THROUGH HIS OWN WIDE GATEWAY

# %%
# %cd /content/drive/MyDrive/LangFolder/DR1
import os
#assign directory
directory = '/content/drive/MyDrive/LangFolder/DR1'

# iterate over files in that directory
# from https://www.geeksforgeeks.org/how-to-iterate-over-files-in-directory-using-python/

your_path = directory
for path, dirs, files in os.walk(your_path):
    print(path)
    print(dirs)
    print(files)

# for filename in os.listdir(directory):
#     tokenizer = Wav2Vec2Tokenizer.from_pretrained('facebook/wav2vec2-base-960h')
#     model = Wav2Vec2ForCTC.from_pretrained('facebook/wav2vec2-base-960h')

#     if filename.endswith('.WAV'):
#       f = os.path.join(directory, filename)
#       if os.path.isfile(f):
#         print(f)
#         audio_file = f
#         waveform, rate = lb.load(audio_file, sr = 16000)
#         input_values = tokenizer(waveform, return_tensors='pt').input_values
#         logits = model(input_values).logits
#         predicted_ids = torch.argmax(logits, dim=-1)
#         transcription = tokenizer.batch_decode(predicted_ids)

#         print(transcription)
# Out:
# /content/drive/MyDrive/LangFolder/DR1
# /content/drive/MyDrive/LangFolder/DR1
# ['MWBT0', 'FELC0', 'MREB0', 'MSJS1', 'MSTK0', 'FJEM0', 'MRJO0', 'MDAB0', 'MJSW0', 'FDAC1', 'FAKS0', '.ipynb_checkpoints']
# []
# /content/drive/MyDrive/LangFolder/DR1/MWBT0
# []
# ['SX113.WAV', 'SI2183.PHN', 'SI923.PHN', 'SI2183.WRD', 'SX293.WRD', 'SX293.PHN', 'SI923.WRD', 'SX113.TXT', 'SX293.TXT', 'SX203.PHN', 'SX23.TXT', 'SX113.PHN', 'SX383.WRD', 'SX293.WAV', 'SA1.WAV', 'SA2.TXT', 'SA2.WRD', 'SX23.WAV', 'SA1.WRD', 'SI2183.WAV', 'SX203.WAV', 'SI1553.PHN', 'SX383.PHN', 'SX203.TXT', 'SA2.PHN', 'SI1553.WRD', 'SI1553.TXT', 'SI2183.TXT', 'SX383.WAV', 'SA2.WAV', 'SI1553.WAV', 'SX23.PHN', 'SX203.WRD', 'SX23.WRD', 'SA1.PHN', 'SA1.TXT', 'SX113.WRD', 'SI923.TXT', 'SI923.WAV', 'SX383.TXT']
# /content/drive/MyDrive/LangFolder/DR1/FELC0
# []
# ...

# %%
#iterating through DR1

import os 
your_pathDR1 = "/content/drive/MyDrive/LangFolder/DR1"

for subfolder_name in os.listdir(your_pathDR1):
    subfolder_path = f"/content/drive/MyDrive/LangFolder/DR1/{subfolder_name}"
    # print(subfolder_path)
    for filename in os.listdir(subfolder_path):
      filename_extension = filename[-4:]
      filename_extension = filename_extension.upper().strip()
      if filename_extension == ".WAV":
        #print(filename) 
        f = os.path.join(subfolder_path, filename)
        if os.path.isfile(f):
          #print(f)
          audio_file = f
          waveform, rate = lb.load(audio_file, sr = 16000)
          input_values = tokenizer(waveform, return_tensors='pt').input_values
          logits = model(input_values).logits
          predicted_ids = torch.argmax(logits, dim=-1)
          transcription = tokenizer.batch_decode(predicted_ids)

          print(transcription)
# Out:
# ['A MUSCULAR ABDOMEN IS GOOD FOR YOU BACK']
# ['PLEASE TAKE THIS DIRTY TABLECLOTH TO THE CLEANERS FOR ME']
# ['SHE HAD YOU DARK SUIT AND GREASY WASH WATER ALL YEAR']
# ['THOSE MUSICIANS HARMONIZE MARVELOUSLY']
# ['BOCKS AR FASCHNUCKS']
# ['THE CAUSEWAY ENDED ABRUPTLY AT THE SHORE']
# ['THE CARPET CLEANERS SHAMPOOD OUR ORIENTAL RUG']
# ["DON'T ASK ME TO CARRY AN OILY RAG LIKE THAT"]
# ['HOWEVER THE LITTLER REMAINED AUGMENTED BY SEVERAL DOZEN LUNCH ROOM SUPPERS']
# ['TO MANY EXPERTS THIS TREND WAS INEVITABLE']
# ['MATERIALS SEREMIC MOUDELING CLAY RED WHITE OR BUFF']
# ['HEAVE ON THOSE ROPES THE BOATS COME UNSTUCK']
# ['ENWAGED NEGOTIATIONS THE INDUSTRY BARGAINS AS A UNIT WITH A SINGLE UNION']
# ['SHE HAD YOUR DARK SUIT IN GREASY WASHWATER ALL YEAR']
# ['THE FISH BEGAN TO LEAP FRANTICALLY ON THE SURFACE OF THE SMALL LAKE']
# ['A CHOSEN FEW WILL BECOME GENEROUS']
# ['THE SMALL BOY PUT THE WORM ON THE HOOK']
# ['ARTIFICIAL INTELLIGENCE IS FOR REAL']
# ...

# %%
#iterating through DR5

your_pathDR5 = "/content/drive/MyDrive/LangFolder/DR5"

for subfolder_name in os.listdir(your_pathDR5):
    subfolder_path = f"/content/drive/MyDrive/LangFolder/DR5/{subfolder_name}"
    # print(subfolder_path)
    for filename in os.listdir(subfolder_path):
      filename_extension = filename[-4:]
      filename_extension = filename_extension.upper().strip()
      if filename_extension == ".WAV":
        #print(filename) 
        f = os.path.join(subfolder_path, filename)
        if os.path.isfile(f):
          #print(f)
          audio_file = f
          waveform, rate = lb.load(audio_file, sr = 16000)
          input_values = tokenizer(waveform, return_tensors='pt').input_values
          logits = model(input_values).logits
          predicted_ids = torch.argmax(logits, dim=-1)
          transcription = tokenizer.batch_decode(predicted_ids)

          print(transcription)
# Out:
# ['HIS MANHOOD HAD BEEN ATTACKED']
# ['PLEASE SAYING JEST THE CLUB THEME']
# ["DON'T ASK ME TO CARRY AN ORLY RAG LIKE THAT"]
# ['HIS SINUOUS MELODY IS A SORT OF NAIVE TRANSCENDENCE OF ALL EXPERIENCE']
# ['BALOGISCUSE READIOACTIVE ICOTOPES TO STUDY MICRO ORGANISMS']
# ['THE FILTERED AIR BENEFITS OLOGIES ASTHMA MSANES HAY FEVER']
# ["THE BARRACOODA RECALLED FROM THE SERPENT'S POISONOUS FANGS"]
# ['SHE HAD YOUR DARK SUIT AND GREASY WASH WATER ALL YEAR']
# ["GENTLY PLACED GEM'S FALM SCULPTURE IN THE BOX"]
# ['THE RIGHT ACTOR STUMPED AWAY IDIOTICALLY']
# ["DON'T ASK ME TO CARRY AN OLLY RAG LIKE THAT"]
# ['SHE HAD YOUR DARK SUIT AND GREASY WASHWATER ALL YEAR']
# ['BUTTER SCOTCH FUDGE GOES WELL WITH VANILICE CREAM']
# ["HOWDING OUT LIKE THIS WON'T GET HIM ANYTHING EXCEPT MORE TROUBLE OR A BULLET"]
# ['AMBE DEXTEROUS PICKPOCKETS ACCOMPLISHE MORE']
# ["PLEDGE TO PARTICIPATE AND NEVADA'S OQUATIC COMPETITION"]
# ['ONER MAMAM']
# ['BUT WE CANNOT START OFF WITH A CLEAN SLATE']
# ...

# %%
#iterating through DR8

your_pathDR8 = "/content/drive/MyDrive/LangFolder/DR8"

for subfolder_name in os.listdir(your_pathDR8):
    subfolder_path = f"/content/drive/MyDrive/LangFolder/DR8/{subfolder_name}"
    # print(subfolder_path)
    for filename in os.listdir(subfolder_path):
      filename_extension = filename[-4:]
      filename_extension = filename_extension.upper().strip()
      if filename_extension == ".WAV":
        #print(filename) 
        f = os.path.join(subfolder_path, filename)
        if os.path.isfile(f):
          #print(f)
          audio_file = f
          waveform, rate = lb.load(audio_file, sr = 16000)
          input_values = tokenizer(waveform, return_tensors='pt').input_values
          logits = model(input_values).logits
          predicted_ids = torch.argmax(logits, dim=-1)
          transcription = tokenizer.batch_decode(predicted_ids)

          print(transcription)
# Out:
# ['SHE HAD YOUR DARK SUIT AND GREASY WASHWATER ALL YEAR']
# ['SONIC ELECTRONICGALVANIC ALL BLANK']
# ['THE CARPET CLEANERS SHAMPOOD OUR ORIENTAL RUG']
# ['HEELS PLACE EMPHASIS ON THE LONG LEGGED SILHOUETTE']
# ['A MUSCULAR APTUMAND AS GOOD FOR YOUR BACK']
# ['THE CAUSEWAY ENDED ABRUPTLY AT THE SHORE']
# ['HE HAD COLLERED ONE OF HIS GENERALS IN PUBLIC']
# ["DON'T ASK ME TO CARRY AN OILY RAG LIKE THAT"]
# ['THOSE MUSICIANS HARMONIZED MARVELLOUSLY']
# ['PLEASE TAKE THE STIRDY TABLE CLOTH TO THE CLEANERS FOR ME']
# ['THE CRANBERRY BOG GETS VERY PRETTY IN AUTUMN']
# ['MOM STRONGLY DISLIKES APPETIZERS']
# ['SHE HAD YOUR DARK SUIT IN GREASY WASHWATER ALL YEAR']
# ['SHE RADIATED WARMTH AND GOOD FELLOWSHIP']
# ["DON'T ASK ME TO CARRY AN OILY RAG LIKE THAT"]
# ['ONLY THOSE STORY TELLERS WILL REMAIN WHO CAN IMITATE THE STYLE OF THE VIRTUOUS']
# ["IT'S HEALTHIER TO COOK WITHOUT SUGAR"]
# ['MAYBE HE WILL HELP TO TURN OUR FAIR CITY INTO A GHOST TOWN']
# ...

# %%
# recordings I took from friend:
# 1. the bravest man amongst us is afraid of himself.
# 2. people know the price of everything, and the value of nothing.
# 3. People are very fond of giving away what they need most themselves.

# %%
# creating my own test sentence (original version)
# the bravest man amongst us is afraif of himself
# sound files are set to 16000 HZ
speech, rate = lb.load("/content/drive/MyDrive/LangFolder/bravest_man.wav",sr=16000)
input_values = tokenizer(speech, return_tensors = 'pt').input_values
#Store logits (non-normalized predictions)
logits = model(input_values).logits
#Store predicted id's
predicted_ids = torch.argmax(logits, dim =-1)
#decode the audio to generate text
transcriptions = tokenizer.decode(predicted_ids[0])
print("Original: " )
print(transcriptions)

# testing transcription of sentence with noise
speech, rate = lb.load("/content/drive/MyDrive/LangFolder/bravest_man_noise.wav",sr=16000)
input_values = tokenizer(speech, return_tensors = 'pt').input_values
#Store logits (non-normalized predictions)
logits = model(input_values).logits
#Store predicted id's
predicted_ids = torch.argmax(logits, dim =-1)
#decode the audio to generate text
transcriptions = tokenizer.decode(predicted_ids[0])
print("With noise: " )
print(transcriptions)
# Out:
# Original:
# THE BRAVEST MAN AMONGST US IS AFRAID OF HIMSELF
# With noise:
# THE BRAVEST MAN AMONG THEM IS AFRAID OF HI FELTH

# %%
# people know the price of everything, and the value of nothing.
# sound files are set to 16000 HZ
speech, rate = lb.load("/content/drive/MyDrive/LangFolder/price.wav",sr=16000)
input_values = tokenizer(speech, return_tensors = 'pt').input_values
#Store logits (non-normalized predictions)
logits = model(input_values).logits
#Store predicted id's
predicted_ids = torch.argmax(logits, dim =-1)
#decode the audio to generate text
transcriptions = tokenizer.decode(predicted_ids[0])
print("Original: " )
print(transcriptions)

# testing transcription of sentence with noise
speech, rate = lb.load("/content/drive/MyDrive/LangFolder/price_noise.wav",sr=16000)
input_values = tokenizer(speech, return_tensors = 'pt').input_values
#Store logits (non-normalized predictions)
logits = model(input_values).logits
#Store predicted id's
predicted_ids = torch.argmax(logits, dim =-1)
#decode the audio to generate text
transcriptions = tokenizer.decode(predicted_ids[0])
print("With noise: " )
print(transcriptions)
# Out:
# Original:
# PEOPLE KNOW THE PRICE OF EVERYTHING AND THE VALLE OF NOTHING
# With noise:
# PEOPLE KNOW THE FACT IF EVERYTHING AND THE VALUE OF NOTHING

# %%
# People are very fond of giving away what they need most themselves.
# sound files are set to 16000 HZ
speech, rate = lb.load("/content/drive/MyDrive/LangFolder/fond.wav",sr=16000)
input_values = tokenizer(speech, return_tensors = 'pt').input_values
#Store logits (non-normalized predictions)
logits = model(input_values).logits
#Store predicted id's
predicted_ids = torch.argmax(logits, dim =-1)
#decode the audio to generate text
transcriptions = tokenizer.decode(predicted_ids[0])
print("Original: " )
print(transcriptions)

# testing transcription of sentence with noise
speech, rate = lb.load("/content/drive/MyDrive/LangFolder/fond_noise.wav",sr=16000)
input_values = tokenizer(speech, return_tensors = 'pt').input_values
#Store logits (non-normalized predictions)
logits = model(input_values).logits
#Store predicted id's
predicted_ids = torch.argmax(logits, dim =-1)
#decode the audio to generate text
transcriptions = tokenizer.decode(predicted_ids[0])
print("With noise: " )
print(transcriptions)
# Out:
# Original:
# PEOPLE ARE VERY FOND OF GIVING AWAY WHAT THEY NEED MOST THEMSELVES
# With noise:
# HE BORE VERY THOUGHT OF GIVING AWAY WITH THE NIGMO HIMSELF
